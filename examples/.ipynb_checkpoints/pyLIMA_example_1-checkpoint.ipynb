# %% [markdown]
# # Welcome to pyLIMA tutorial! #
# Let's learn how pyLIMA works by fitting an example.
#
# To obtain working link to the documentation, you need to :
#
# make html
#
# in the doc directory.
#
# Please help yourself with the [pyLIMA documentation](file/../../doc/build/html/index.html)

# %%
### First import the required libraries
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import os, sys
lib_path = os.path.abspath(os.path.join('../'))
sys.path.append(lib_path)

from pyLIMA import event
from pyLIMA import telescopes
from pyLIMA import microlmodels

# %% [markdown]
# Nothing wrong?
# Let's go ahead.

# %% [markdown]
# # The event module #
# We have to define an [event](file/../../doc/build/html/pyLIMA.event.html) object.

# %%
### Create an event object. You can choose the name and RA,DEC in degrees :

your_event = event.Event()
your_event.name = 'your choice'
your_event.ra = 269.39166666666665 
your_event.dec = -29.22083333333333

# %% [markdown]
# # The telescopes module#
# To insert data to your event, we need to define  [telescopes](file/../../doc/build/html/pyLIMA.telescopes.html) objects and just add it
# to the event object telescope list.

# %%
### Now we need some observations. That's good, we obtain some data on two
### telescopes. Both are in I band and magnitude units :

data_1 = np.loadtxt('./Survey_1.dat')
telescope_1 = telescopes.Telescope(name='OGLE', camera_filter='I', light_curve_magnitude=data_1)

data_2 = np.loadtxt('./Followup_1.dat')
telescope_2 = telescopes.Telescope(name='LCOGT', camera_filter='I', light_curve_magnitude=data_2)

### Add the telescopes to your event :
your_event.telescopes.append(telescope_1)
your_event.telescopes.append(telescope_2)

### Find the survey telescope :
your_event.find_survey('OGLE')

### Sanity check
your_event.check_event()
# Out:
# check_event  : Everything looks fine, this event can be fitted

# %% [markdown]
# # The model module #
# We have now to define a [model](file/../../doc/build/html/pyLIMA.microlmodels.html) object that summarizes what kind of model you want to fit.
# Let's start with a basic PSPL.

# %%
### Construct the model you want to fit. Let's go basic with a PSPL, without second_order effects :
model_1 = microlmodels.create_model('PSPL', your_event)

# %% [markdown]
# # We are all set now. Just fit by choosing one method #
# For a summary of fitting options, please go [there](file/../../doc/build/html/pyLIMA.microlfits.html)

# %%
### Let's try with the simplest Levenvberg_Marquardt algorithm :
your_event.fit(model_1,'LM')

### Let's see some plots.
your_event.fits[0].produce_outputs()
print 'Chi2_LM :',your_event.fits[0].outputs.fit_parameters.chichi
plt.show()
# Out:
# Start fit on your choice, with model PSPL and method LM
# check_event  : Everything looks fine, this event can be fitted
# initial_guess  : Initial parameters guess SUCCESS
# [80.265925305401296, 0.012201973710850926, 10.948617613093674, 3139.003511812075, 0.0, 118934.71374344986, -6.346941722357279]
# lmarquardt  : Levenberg_marquardt fit SUCCESS
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# Chi2_LM : 8440.16950162

# %% [markdown]
# There is some residuals close to the peak, right? And the Chi2 is high also. Maybe the LM algorithm performs poorly, let's try something more powerfull.
#
# You can zoom close to the peak to see what is going on.

# %%
### Let's try with differential evolution  algorithm. WAIT UNTIL THE FIGURE POP UP.
your_event.fit(model_1,'DE')
your_event.fits[1].produce_outputs()
print 'Chi2_DE :',your_event.fits[1].outputs.fit_parameters.chichi
plt.show()
# Out:
# Start fit on your choice, with model PSPL and method DE
# check_event  : Everything looks fine, this event can be fitted
# differential_evolution step 1: f(x)= 1.6972e+06
# differential_evolution step 2: f(x)= 1.62595e+06
# differential_evolution step 3: f(x)= 1.62595e+06
# differential_evolution step 4: f(x)= 1.62595e+06
# differential_evolution step 5: f(x)= 1.62595e+06
# differential_evolution step 6: f(x)= 1.44971e+06
# differential_evolution step 7: f(x)= 1.44971e+06
# differential_evolution step 8: f(x)= 1.04524e+06
# differential_evolution step 9: f(x)= 1.04524e+06
# differential_evolution step 10: f(x)= 1.04524e+06
# differential_evolution step 11: f(x)= 1.04524e+06
# differential_evolution step 12: f(x)= 1.04524e+06
# differential_evolution step 13: f(x)= 1.04524e+06
# differential_evolution step 14: f(x)= 1.04524e+06
# differential_evolution step 15: f(x)= 1.04524e+06
# differential_evolution step 16: f(x)= 255467
# differential_evolution step 17: f(x)= 255467
# differential_evolution step 18: f(x)= 255467
# differential_evolution step 19: f(x)= 255467
# differential_evolution step 20: f(x)= 255467
# differential_evolution step 21: f(x)= 255467
# differential_evolution step 22: f(x)= 255467
# differential_evolution step 23: f(x)= 255467
# differential_evolution step 24: f(x)= 255467
# differential_evolution step 25: f(x)= 255467
# differential_evolution step 26: f(x)= 255467
# differential_evolution step 27: f(x)= 255467
# differential_evolution step 28: f(x)= 255467
# differential_evolution step 29: f(x)= 255467
# differential_evolution step 30: f(x)= 255467
# differential_evolution step 31: f(x)= 255467
# differential_evolution step 32: f(x)= 255467
# differential_evolution step 33: f(x)= 255467
# differential_evolution step 34: f(x)= 255467
# differential_evolution step 35: f(x)= 242329
# differential_evolution step 36: f(x)= 242329
# differential_evolution step 37: f(x)= 242329
# differential_evolution step 38: f(x)= 242329
# differential_evolution step 39: f(x)= 242329
# differential_evolution step 40: f(x)= 242329
# differential_evolution step 41: f(x)= 207071
# differential_evolution step 42: f(x)= 207071
# differential_evolution step 43: f(x)= 108305
# differential_evolution step 44: f(x)= 108305
# differential_evolution step 45: f(x)= 108305
# differential_evolution step 46: f(x)= 108305
# differential_evolution step 47: f(x)= 108305
# differential_evolution step 48: f(x)= 108305
# differential_evolution step 49: f(x)= 108305
# differential_evolution step 50: f(x)= 108305
# differential_evolution step 51: f(x)= 108305
# differential_evolution step 52: f(x)= 108305
# differential_evolution step 53: f(x)= 108305
# differential_evolution step 54: f(x)= 108305
# differential_evolution step 55: f(x)= 108305
# differential_evolution step 56: f(x)= 108305
# differential_evolution step 57: f(x)= 97715.6
# differential_evolution step 58: f(x)= 97715.6
# differential_evolution step 59: f(x)= 42984.3
# differential_evolution step 60: f(x)= 42984.3
# differential_evolution step 61: f(x)= 42984.3
# differential_evolution step 62: f(x)= 42984.3
# differential_evolution step 63: f(x)= 42984.3
# differential_evolution step 64: f(x)= 42984.3
# differential_evolution step 65: f(x)= 42984.3
# differential_evolution step 66: f(x)= 42984.3
# differential_evolution step 67: f(x)= 42984.3
# differential_evolution step 68: f(x)= 42984.3
# differential_evolution step 69: f(x)= 37296.9
# differential_evolution step 70: f(x)= 35808.2
# differential_evolution step 71: f(x)= 35808.2
# differential_evolution step 72: f(x)= 35808.2
# differential_evolution step 73: f(x)= 35808.2
# differential_evolution step 74: f(x)= 23003.5
# differential_evolution step 75: f(x)= 12703.6
# differential_evolution step 76: f(x)= 12703.6
# differential_evolution step 77: f(x)= 12703.6
# differential_evolution step 78: f(x)= 12703.6
# differential_evolution step 79: f(x)= 12703.6
# differential_evolution step 80: f(x)= 12703.6
# differential_evolution step 81: f(x)= 12703.6
# differential_evolution step 82: f(x)= 12703.6
# differential_evolution step 83: f(x)= 12703.6
# differential_evolution step 84: f(x)= 12573.1
# differential_evolution step 85: f(x)= 9883.28
# differential_evolution step 86: f(x)= 9883.28
# differential_evolution step 87: f(x)= 9883.28
# differential_evolution step 88: f(x)= 9883.28
# differential_evolution step 89: f(x)= 9883.28
# differential_evolution step 90: f(x)= 9883.28
# differential_evolution step 91: f(x)= 9883.28
# differential_evolution step 92: f(x)= 9883.28
# differential_evolution step 93: f(x)= 9883.28
# differential_evolution step 94: f(x)= 9883.28
# differential_evolution step 95: f(x)= 9883.28
# differential_evolution step 96: f(x)= 8717.38
# differential_evolution step 97: f(x)= 8717.38
# differential_evolution step 98: f(x)= 8717.38
# differential_evolution step 99: f(x)= 8717.38
# differential_evolution step 100: f(x)= 8698.73
# differential_evolution step 101: f(x)= 8698.73
# differential_evolution step 102: f(x)= 8693.64
# differential_evolution step 103: f(x)= 8598.83
# differential_evolution step 104: f(x)= 8598.83
# differential_evolution step 105: f(x)= 8598.83
# differential_evolution step 106: f(x)= 8478.08
# differential_evolution step 107: f(x)= 8478.08
# differential_evolution step 108: f(x)= 8478.08
# differential_evolution step 109: f(x)= 8478.08
# differential_evolution step 110: f(x)= 8478.08
# differential_evolution step 111: f(x)= 8478.08
# differential_evolution step 112: f(x)= 8472.39
# differential_evolution step 113: f(x)= 8472.39
# differential_evolution step 114: f(x)= 8472.39
# differential_evolution step 115: f(x)= 8472.39
# differential_evolution step 116: f(x)= 8471.9
# differential_evolution step 117: f(x)= 8471.9
# differential_evolution step 118: f(x)= 8471.9
# differential_evolution step 119: f(x)= 8470.8
# differential_evolution step 120: f(x)= 8470.8
# differential_evolution step 121: f(x)= 8447.98
# differential_evolution step 122: f(x)= 8447.98
# differential_evolution step 123: f(x)= 8447.98
# differential_evolution step 124: f(x)= 8447.98
# differential_evolution step 125: f(x)= 8447.98
# differential_evolution step 126: f(x)= 8447.98
# differential_evolution step 127: f(x)= 8447.98
# differential_evolution step 128: f(x)= 8447.98
# differential_evolution step 129: f(x)= 8447.98
# differential_evolution step 130: f(x)= 8447.98
# differential_evolution step 131: f(x)= 8447.98
# differential_evolution step 132: f(x)= 8442.44
# differential_evolution step 133: f(x)= 8442.44
# differential_evolution step 134: f(x)= 8442.44
# differential_evolution step 135: f(x)= 8442.44
# differential_evolution step 136: f(x)= 8442.44
# differential_evolution step 137: f(x)= 8442.44
# differential_evolution step 138: f(x)= 8442.44
# differential_evolution step 139: f(x)= 8442.44
# differential_evolution step 140: f(x)= 8442.44
# differential_evolution step 141: f(x)= 8442.44
# differential_evolution step 142: f(x)= 8442.44
# differential_evolution step 143: f(x)= 8442.44
# differential_evolution step 144: f(x)= 8442.44
# differential_evolution step 145: f(x)= 8441.62
# differential_evolution step 146: f(x)= 8441.62
# differential_evolution step 147: f(x)= 8441.62
# differential_evolution step 148: f(x)= 8441.62
# differential_evolution step 149: f(x)= 8441.62
# differential_evolution step 150: f(x)= 8441.53
# differential_evolution step 151: f(x)= 8440.39
# differential_evolution step 152: f(x)= 8440.39
# differential_evolution step 153: f(x)= 8440.39
# differential_evolution step 154: f(x)= 8440.39
# differential_evolution step 155: f(x)= 8440.39
# differential_evolution step 156: f(x)= 8440.24
# differential_evolution step 157: f(x)= 8440.24
# differential_evolution step 158: f(x)= 8440.24
# differential_evolution step 159: f(x)= 8440.24
# differential_evolution step 160: f(x)= 8440.24
# differential_evolution step 161: f(x)= 8440.24
# differential_evolution step 162: f(x)= 8440.24
# differential_evolution step 163: f(x)= 8440.24
# differential_evolution step 164: f(x)= 8440.24
# differential_evolution step 165: f(x)= 8440.24
# differential_evolution step 166: f(x)= 8440.24
# differential_evolution step 167: f(x)= 8440.24
# differential_evolution step 168: f(x)= 8440.24
# differential_evolution step 169: f(x)= 8440.24
# differential_evolution step 170: f(x)= 8440.24
# differential_evolution step 171: f(x)= 8440.24
# differential_evolution step 172: f(x)= 8440.24
# differential_evolution step 173: f(x)= 8440.24
# DE converge to objective function : f(x) =  8440.16949285
# [79.96375903098156, 0.011068540710945544, 9.607658068315532, 3153.1269255553225, -0.007527123647861662, 106079.56528917768, -0.44396689605978257]
# lmarquardt  : Levenberg_marquardt fit SUCCESS
# differential_evolution  : Differential evolution fit SUCCESS
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# Chi2_DE : 8440.16949285

# %% [markdown]
# Well, that's not really better. Maybe there is some other effects in the model?
# Let's try an FSPL model!
#
#
# You can zoom close to the peak to see what is going on.

# %%
### Let's go basic for FSPL :
model_2 = microlmodels.create_model('FSPL', your_event)

your_event.fit(model_2,'LM')

### Let's see some plots. You can zoom close to the peak to see what is going on. CLOSE THE FIGURE TO CONTINUE.
your_event.fits[-1].produce_outputs()
print 'Chi2_LM :',your_event.fits[-1].outputs.fit_parameters.chichi
plt.show()

# %% [markdown]
# That's better, but there is still some deviations around 80.1 days. Any ideas?
#
# ...
#
# ...
#
# ...
#
# What about some limb-darkening effects? Let's try this

# %%
### set gamma for each telescopes :

your_event.telescopes[0].gamma = 0.5
your_event.telescopes[1].gamma = 0.5

### Fit again
your_event.fit(model_2,'LM')

your_event.fits[-1].produce_outputs()
print 'Chi2_LM :',your_event.fits[-1].outputs.fit_parameters.chichi
plt.show()

# %% [markdown]
# Wrong back! What is going on here? Maybe the LM method is confused by the limb-darkening coefficients? Let's try something else.

# %%
# We can use a previous good fit for starting initial parameters as guesses

initial_parameters = [ getattr(your_event.fits[-2].outputs.fit_parameters, key) for 
                      key in your_event.fits[-2].outputs.fit_parameters._fields]

model_2.parameters_guess = initial_parameters

#Fit again
your_event.fit(model_2,'LM')

your_event.fits[-1].produce_outputs()
print 'Chi2_LM :',your_event.fits[-1].outputs.fit_parameters.chichi
plt.show()

# %% [markdown]
# This looks good. We can confirm with the DE method.

# %%
### Fit again, and wait the figures....
your_event.fit(model_2,'DE')

your_event.fits[-1].produce_outputs()
print 'Chi2_DE :',your_event.fits[-1].outputs.fit_parameters.chichi
plt.show()

# %% [markdown]
# That is similar fit Chi^2.
#
# Here we go!
#
# You can zoom close to the peak to see what is going on. CLOSE THE FIGURE TO CONTINUE.
#
# Let's compare the fitting values with the injected model :

# %%
print 'Parameters', ' Model','   Fit','     Errors'
print '-----------------------------------'
print 't_o', '        79.9309 ',str(your_event.fits[-1].outputs.fit_parameters.to)[:7],'',str(your_event.fits[-1].outputs.fit_errors.err_to)[:7] 
print 'u_o', '        0.00826 ',str(your_event.fits[-1].outputs.fit_parameters.uo)[:7],'',str(your_event.fits[-1].outputs.fit_errors.err_uo)[:7]
print 't_E', '        10.1171 ',str(your_event.fits[-1].outputs.fit_parameters.tE)[:7],'',str(your_event.fits[-1].outputs.fit_errors.err_tE)[:7]
print 'rho', '        0.02268 ',str(your_event.fits[-1].outputs.fit_parameters.rho)[:7],'',str(your_event.fits[-1].outputs.fit_errors.err_rho)[:7]
print 'fs_OGLE', '    2915.76 ',str(your_event.fits[-1].outputs.fit_parameters.fs_OGLE)[:7],'',str(your_event.fits[-1].outputs.fit_errors.err_fs_OGLE)[:7]
print 'g_OGLE', '     0.07195 ',str(your_event.fits[-1].outputs.fit_parameters.g_OGLE)[:7],'',str(your_event.fits[-1].outputs.fit_errors.err_g_OGLE)[:7]
print 'fs_LCOGT', '   92936.7 ',str(your_event.fits[-1].outputs.fit_parameters.fs_LCOGT)[:7],'',str(your_event.fits[-1].outputs.fit_errors.err_fs_LCOGT)[:7]
print 'g_LCOGT', '    0.52460 ',str(your_event.fits[-1].outputs.fit_parameters.g_LCOGT)[:7],'',str(your_event.fits[-1].outputs.fit_errors.err_g_LCOGT)[:7]

# %% [markdown]
# # Bonus Track #
# What about some MCMC?

# %%
### Fit again, but using MCMC now. TAKE A WHILE....Wait until figures pop up.
your_event.fit(model_2,'MCMC',flux_estimation_MCMC='polyfit')
print 'The fitting process is finished now, let produce some outputs....'

your_event.fits[-1].produce_outputs()

plt.show()
